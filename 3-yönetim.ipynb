# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('satislar.csv')

# %%
df.head()
# Out:
#    Aylar  Satislar
# 0      8   19671.5
# 1     10   23102.5
# 2     11   18865.5
# 3     13   21762.5
# 4     14   19945.5

# %%
y = df["Aylar"].values
x = df.drop("Aylar", axis=1).values

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
y_train = scaler.fit_transform(y_train.reshape(-1, 1))
y_test = scaler.transform(y_test.reshape(-1, 1))

# %%
x_train
# Out:
# array([[28321. ],
#        [33014.5],
#        [32222.5],
#        [30555.5],
#        [56906. ],
#        [45869. ],
#        [23102.5],
#        [60936. ],
#        [30075. ],
#        [19945.5],
#        [40681.5],
#        [ 4697. ],
#        [28594.5],
#        [27222.5],
#        [52791. ],
#        [21762.5],
#        [19671.5],
#        [49136.5],
#        [33969. ],
#        [28478.5]])

# %%
x_test
# Out:
# array([[18865.5],
#        [61195.5],
#        [28540.5],
#        [31609. ],
#        [58484.5],
#        [54715.5],
#        [56317.5],
#        [27897. ],
#        [41544. ],
#        [50651. ]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
tahmin =lr.predict(x_test)

# %%
tahmin
# Out:
# array([16.84523537, 54.28938913, 25.40351998, 28.11784518, 51.89130029,
#        48.55732874, 49.97442145, 24.83429454, 36.90611987, 44.96196462])

# %%
sorted_indices_x = np.argsort(x_train[:, 0])
x_train = x_train[sorted_indices_x]

sorted_indices_y = np.argsort(y_train)
y_train = y_train[sorted_indices_y]

# %%
plt.plot(y_train, x_train)
plt.plot(lr.predict(x_test),x_test)
