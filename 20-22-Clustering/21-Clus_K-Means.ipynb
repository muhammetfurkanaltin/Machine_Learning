# %% [markdown]
# ## K-Means

# %% [markdown]
# https://scikit-learn.org/stable/modules/clustering.html

# %% [markdown]
# ### 21.1 Nasıl Çalışır ?

# %% [markdown]
# Kaç küme olacıgna kullanıcıdan parametre olarak seçilir.
#
# Rasgele olarak k merkez noktası seçilir
#
# Her veri örneği en yakın merkez noktasına göre ilgili kümeye atanır.
#
# Her küme için yeni merkez noktaları hesaplnarak merkez noktaları kaydırılır
#
# Yeni merkez noktalarına göre

# %% [markdown]
# ### 21.2 Başlangıç Tuzağı

# %% [markdown]
# K-Means++
#
# WCSS

# %% [markdown]
# ### 21.4_K-Means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
data  = pd.read_csv('musteriler.csv')

x = data.iloc[:,3:].values

data.head()
# Out:
#    No Cinsiyet  Yas  Hacim  Maas
# 0   1        K   60  69900  6325
# 1   2        K   30  79000  5200
# 2   3        E   52  85500  7825
# 3   4        E   57  17100  8375
# 4   5        E   55   5500  5450

# %%
kmeans = KMeans(n_clusters=3, init='k-means++')
kmeans.fit(x)
print(kmeans.cluster_centers_)
# Out:
# [[ 58643.47826087   5844.92753623]
#  [104386.95652174   7289.13043478]
#  [ 22069.41176471   5320.88235294]]

# %%
sonuclar = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=34)
    kmeans.fit(x)
    sonuclar.append(kmeans.inertia_)
    
plt.plot(range(1,11), sonuclar)

# %% [markdown]
# Burda dirsek noktalarına bakılarak bir k seçilebilir bunlarda "2-3-4" olabilir.

# %%
kmeans = KMeans(n_clusters=4, init='k-means++')
kmeans.fit(x)
print(kmeans.cluster_centers_)

Y_tahmin = kmeans.fit_predict(x)


plt.scatter(x[Y_tahmin == 0,0], x[Y_tahmin == 0,1], s=100, c='red')
plt.scatter(x[Y_tahmin == 1,0], x[Y_tahmin == 1,1], s=100, c='blue')
plt.scatter(x[Y_tahmin == 2,0], x[Y_tahmin == 2,1], s=100, c='green')
plt.scatter(x[Y_tahmin == 3,0], x[Y_tahmin == 3,1], s=100, c='yellow')
# Out:
# [[ 81588.46153846   6765.38461538]
#  [ 16245.76271186   5363.13559322]
#  [122140.           8000.        ]
#  [ 44640.57971014   5255.79710145]]
