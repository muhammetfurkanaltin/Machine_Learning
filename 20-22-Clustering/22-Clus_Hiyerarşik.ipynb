# %% [markdown]
# ## Hiyerarşik

# %% [markdown]
# #### 1-Agglomerative
# Her veri bir küme / bölüt ile başlar
#
# En yakın ikişer komşuyu alıp ikişerli küme / bölüt olşturulur
#
# En yakın iki kümeyi alıp yeni bir bölüt oluşturulur
#
# Bir önceki adım tek bir bölüt / küme olana kadar devam eder.
#
# #### 2-Divisive
# Agglomerative Tam Tersidir

# %% [markdown]
# ### 22.2 Dendogram

# %% [markdown]
# Farklı Mesafe Stratejeleri
#
# Dendrogramda en uzun dikey çizginin altından yatay bir çizgi çekerek, bu çizginin kestiği dikey çizgi sayısı kadar küme (k) oluşturulur. ( Serbest olma durumunda )

# %% [markdown]
# ### 22.3_Hiyerarşik

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import AgglomerativeClustering

# %%
data  = pd.read_csv('musteriler.csv')

x = data.iloc[:,3:].values

data.head()
# Out:
#    No Cinsiyet  Yas  Hacim  Maas
# 0   1        K   60  69900  6325
# 1   2        K   30  79000  5200
# 2   3        E   52  85500  7825
# 3   4        E   57  17100  8375
# 4   5        E   55   5500  5450

# %%
ac = AgglomerativeClustering(n_clusters=4, metric='euclidean', linkage='ward')
Y_tahmin = ac.fit_predict(x)
print(Y_tahmin)
# Out:
# [0 0 0 2 2 2 2 0 2 1 1 0 1 2 0 3 0 2 0 0 2 2 0 1 3 1 2 0 2 1 2 1 1 0 1 1 1
#  2 1 3 0 2 0 2 2 1 1 1 1 3 2 0 3 3 0 0 2 0 1 0 3 0 1 2 1 2 1 0 1 2 0 0 0 0
#  2 2 3 0 1 2 2 2 1 1 3 0 0 1 2 2 0 2 3 1 2 1 2 0 2 2 1 3 0 2 2 0 0 1 1 3 3
#  0 0 0 0 1 2 0 1 1 2 1 0 0 0 1 2 2 3 2 2 1 1 1 1 2 1 1 0 1 0 2 1 1 0 1 1 1
#  1 2 1 1 0 2 1 3 2 1 3 2 1 1 2 1 2 1 1 0 2 2 0 2 2 1 1 2 2 1 3 1 1 0 1 3 0
#  3 2 2 1 2 1 2 1 0 2 0 0 1 1 1]

# %%
plt.scatter(x[Y_tahmin == 0,0], x[Y_tahmin == 0,1], s=100, c='red')
plt.scatter(x[Y_tahmin == 1,0], x[Y_tahmin == 1,1], s=100, c='blue')
plt.scatter(x[Y_tahmin == 2,0], x[Y_tahmin == 2,1], s=100, c='green')
plt.scatter(x[Y_tahmin == 3,0], x[Y_tahmin == 3,1], s=100, c='yellow')

# %%
import scipy.cluster.hierarchy as sch

den = sch.dendrogram(sch.linkage(x, method='ward'))
plt.show()
